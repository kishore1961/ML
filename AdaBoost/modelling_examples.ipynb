# %%
import numpy as np
import sklearn
from sklearn import datasets, model_selection, metrics
import matplotlib.pyplot as plt

# Importing our from scratch models
from decision_tree import DecisionTree
from random_forest import RandomForestClassifier
from adaboost import AdaBoostClassifier

# %% [markdown]
# # DecisionTree Examples

# %% [markdown]
# ## Training on Iris Dataset

# %%
iris = datasets.load_iris()

X = np.array(iris.data)
Y = np.array(iris.target)
iris_feature_names = iris.feature_names

X_train, X_test, Y_train, Y_test = model_selection.train_test_split(X, Y, test_size=0.25, random_state=0)
print("Train Shape:", X_train.shape)
print("Train Shape:", X_test.shape)
# Out:
# Train Shape: (112, 4)
# Train Shape: (38, 4)

# %%
# Building the tree
my_tree = DecisionTree(max_depth=4, min_samples_leaf=1, min_information_gain=0)
my_tree.train(X_train, Y_train)

# %%
# Let's see the tree
my_tree.print_tree()
# Out:
#                                                                 -> LEAF | Label Counts = 0.0->1 | Pred Probs = [1. 0. 0.]
#                                                 -> NODE | Information Gain = 0.0 | Split IF X[0] < 4.4 THEN left O/W right
#                                                                 -> LEAF | Label Counts = 0.0->8 | Pred Probs = [1. 0. 0.]
#                                 -> NODE | Information Gain = 0.0 | Split IF X[0] < 4.775 THEN left O/W right
#                                                                 -> LEAF | Label Counts = 0.0->6 | Pred Probs = [1. 0. 0.]
#                                                 -> NODE | Information Gain = 0.0 | Split IF X[0] < 5.0 THEN left O/W right
#                                                                 -> LEAF | Label Counts = 0.0->21 | Pred Probs = [1. 0. 0.]
#                 -> NODE | Information Gain = 0.6731015728685515 | Split IF X[3] < 0.525 THEN left O/W right
#                                                 -> LEAF | Label Counts = 0.0->1 | Pred Probs = [1. 0. 0.]
#                                 -> NODE | Information Gain = 0.41381685030363374 | Split IF X[3] < 1.0 THEN left O/W right
#                                                                 -> LEAF | Label Counts = 1.0->3 | Pred Probs = [0. 1. 0.]
#                                                 -> NODE | Information Gain = 0.0 | Split IF X[0] < 5.3 THEN left O/W right
#                                                                 -> LEAF | Label Counts = 1.0->8 | Pred Probs = [0. 1. 0.]
# -> NODE | Information Gain = 0.7095311377468411 | Split IF X[3] < 1.3 THEN left O/W right
#                                                                 -> LEAF | Label Counts = 1.0->2, 2.0->1 | Pred Probs = [0.         0.66666667 0.33333333]
#                                                 -> NODE | Information Gain = 0.14865258200778284 | Split IF X[0] < 5.6 THEN left O/W right
#                                                                 -> LEAF | Label Counts = 1.0->17 | Pred Probs = [0. 1. 0.]
#                                 -> NODE | Information Gain = 0.23041810979993893 | Split IF X[2] < 4.8 THEN left O/W right
#                                                                 -> LEAF | Label Counts = 1.0->1, 2.0->4 | Pred Probs = [0.  0.2 0.8]
#                                                 -> NODE | Information Gain = 0.22943684069673975 | Split IF X[1] < 3.0 THEN left O/W right
#                                                                 -> LEAF | Label Counts = 1.0->3, 2.0->1 | Pred Probs = [0.   0.75 0.25]
#                 -> NODE | Information Gain = 0.6088858430669675 | Split IF X[2] < 5.1 THEN left O/W right
#                                                                 -> LEAF | Label Counts = 2.0->2 | Pred Probs = [0. 0. 1.]
#                                                 -> NODE | Information Gain = 0.0 | Split IF X[0] < 5.85 THEN left O/W right
#                                                                 -> LEAF | Label Counts = 2.0->5 | Pred Probs = [0. 0. 1.]
#                                 -> NODE | Information Gain = 0.0 | Split IF X[0] < 6.4 THEN left O/W right
#                                                                 -> LEAF | Label Counts = 2.0->7 | Pred Probs = [0. 0. 1.]
#                                                 -> NODE | Information Gain = 0.0 | Split IF X[0] < 6.65 THEN left O/W right
#                                                                 -> LEAF | Label Counts = 2.0->21 | Pred Probs = [0. 0. 1.]

# %%
# Let's see the Train performance
train_preds = my_tree.predict(X_set=X_train)
print("TRAIN PERFORMANCE")
print("Train size", len(Y_train))
print("True preds", sum(train_preds == Y_train))
print("Train Accuracy", sum(train_preds == Y_train) / len(Y_train))
# Out:
# TRAIN PERFORMANCE
# Train size 112
# True preds 109
# Train Accuracy 0.9732142857142857

# %%
# Let's see the Test performance
test_preds = my_tree.predict(X_set=X_test)
print("TEST PERFORMANCE")
print("Test size", len(Y_test))
print("True preds", sum(test_preds == Y_test))
print("Accuracy", sum(test_preds == Y_test) / len(Y_test))
# Out:
# TEST PERFORMANCE
# Test size 38
# True preds 35
# Accuracy 0.9210526315789473

# %%
# Feature importance
plt.bar(range(len(my_tree.feature_importances)), 
        list(my_tree.feature_importances.values()), tick_label=iris_feature_names)
plt.title("Feature Importance")
plt.xlabel("Feature")
plt.xticks(rotation=90)
plt.ylabel("Feature Importance")
plt.show()

# %% [markdown]
# ## Training on Breast Cancer Dataset

# %%
# Load data
data = datasets.load_breast_cancer()
X = data.data
Y = data.target
breast_cancer_feature_names = data.feature_names

X_train, X_test, Y_train, Y_test = model_selection.train_test_split(X, Y, test_size=0.2, random_state=0)
print("Train Shape:", X_train.shape)
print("Train Shape:", X_test.shape)
# Out:
# Train Shape: (455, 30)
# Train Shape: (114, 30)

# %%
# Building the tree
my_tree_2 = DecisionTree(max_depth=4, min_samples_leaf=5, min_information_gain=0.05)
my_tree_2.train(X_train, Y_train)

# %%
my_tree_2.print_tree()
# Out:
#                                 -> LEAF | Label Counts = 0.0->6, 1.0->249 | Pred Probs = [0.02352941 0.97647059]
#                 -> NODE | Information Gain = 0.24446648320004927 | Split IF X[27] < 0.112 THEN left O/W right
#                                                                 -> LEAF | Label Counts = 1.0->16 | Pred Probs = [0. 1.]
#                                                 -> NODE | Information Gain = 0.20443400292496505 | Split IF X[26] < 0.24924999999999997 THEN left O/W right
#                                                                 -> LEAF | Label Counts = 0.0->24, 1.0->24 | Pred Probs = [0.5 0.5]
#                                 -> NODE | Information Gain = 0.28620952259378585 | Split IF X[27] < 0.177425 THEN left O/W right
#                                                 -> LEAF | Label Counts = 0.0->22 | Pred Probs = [1. 0.]
# -> NODE | Information Gain = 0.4649825668927295 | Split IF X[20] < 18.409999999999997 THEN left O/W right
#                 -> LEAF | Label Counts = 0.0->113, 1.0->1 | Pred Probs = [0.99122807 0.00877193]

# %%
# Let's see the Train performance
train_preds = my_tree_2.predict(X_set=X_train)
print("TRAIN PERFORMANCE")
print("Train size", len(Y_train))
print("True preds", sum(train_preds == Y_train))
print("Train Accuracy", sum(train_preds == Y_train) / len(Y_train))
# Out:
# TRAIN PERFORMANCE
# Train size 455
# True preds 424
# Train Accuracy 0.9318681318681319

# %%
# Let's see the Test performance
test_preds = my_tree_2.predict(X_set=X_test)
print("TEST PERFORMANCE")
print("Test size", len(Y_test))
print("True preds", sum(test_preds == Y_test))
print("Accuracy", sum(test_preds == Y_test) / len(Y_test))
# Out:
# TEST PERFORMANCE
# Test size 114
# True preds 103
# Accuracy 0.9035087719298246

# %%
# Feature importance
plt.bar(range(len(my_tree_2.feature_importances)), 
        list(my_tree_2.feature_importances.values()), tick_label=breast_cancer_feature_names)
plt.xticks(rotation=90)
plt.title("Feature Importance")
plt.xlabel("Feature")
plt.ylabel("Feature Importance")
plt.show()

# %% [markdown]
# ## Training on Diabetes Data (from OpenML)

# %%
diabetes = datasets.fetch_openml(name="diabetes", as_frame=False)
# Out:
# c:\Users\cheekish\Desktop\ML\ml\Lib\site-packages\sklearn\datasets\_openml.py:323: UserWarning: Multiple active versions of the dataset matching the name diabetes exist. Versions may be fundamentally different, returning version 1. Available versions:
# - version 1, status: active
#   url: https://www.openml.org/search?type=data&id=37
# - version 5, status: active
#   url: https://www.openml.org/search?type=data&id=42608
#
#   warn(warning_msg)

# %%
diabetes_features = np.array(diabetes.data)
print(diabetes_features.shape)
diabetes_labels = np.array([y=="tested_positive" for y in diabetes.target]).astype(int)
print(diabetes_labels.shape)
# Out:
# (768, 8)
# (768,)

# %%
X_train, X_test, Y_train, Y_test = model_selection.train_test_split(diabetes_features, diabetes_labels, test_size=0.2, random_state=0)

# %%
# Lets see how model performs with different max_depth thresholds

train_accuracy_dict = {}
test_accuracy_dict = {}
# depth_occured = {}

for depth in range(2, 21):
    tree_model = DecisionTree(max_depth=depth, min_samples_leaf=1)
    tree_model.train(X_train, Y_train)

    # depth_occured[depth] = tree_model.current_de

    # Train performance
    train_preds = tree_model.predict(X_set=X_train)
    train_accuracy = sum(train_preds == Y_train) / len(Y_train)
    train_accuracy_dict[depth] = train_accuracy

    # Test performance
    test_preds = tree_model.predict(X_set=X_test)
    test_accuracy = sum(test_preds == Y_test) / len(Y_test)
    test_accuracy_dict[depth] = test_accuracy

# %%
plt.plot(train_accuracy_dict.keys(), train_accuracy_dict.values(), label="Train")
plt.plot(test_accuracy_dict.keys(), test_accuracy_dict.values(), label="Test")
plt.title("Accuracy vs Depth for Diabetes Dataset")
plt.xlabel("Max Depth Threshold")
plt.ylabel("Accuracy")
plt.legend()
plt.ylim(bottom=0.0)
plt.show()

# %% [markdown]
# #### We can see that the tree starts to overfit after max_depth exceeds 5

# %%
opt_tree_model = DecisionTree(max_depth=5, min_samples_leaf=1)
opt_tree_model.train(X_train, Y_train)

# %%
train_preds = opt_tree_model.predict(X_set=X_train)
print("TRAIN PERFORMANCE")
print("Train size", len(Y_train))
print("True preds", sum(train_preds == Y_train))
print("Accuracy", sum(train_preds == Y_train) / len(Y_train))

test_preds = opt_tree_model.predict(X_set=X_test)
print("TEST PERFORMANCE")
print("Test size", len(Y_test))
print("True preds", sum(test_preds == Y_test))
print("Accuracy", sum(test_preds == Y_test) / len(Y_test))
# Out:
# TRAIN PERFORMANCE
# Train size 614
# True preds 484
# Accuracy 0.7882736156351792
# TEST PERFORMANCE
# Test size 154
# True preds 120
# Accuracy 0.7792207792207793

# %%
opt_tree_model.print_tree()
# Out:
#                                                                 -> LEAF | Label Counts = 0.0->9 | Pred Probs = [1. 0.]
#                                                 -> NODE | Information Gain = 0.0 | Split IF X[0] < 1.0 THEN left O/W right
#                                                                 -> LEAF | Label Counts = 0.0->48 | Pred Probs = [1. 0.]
#                                 -> NODE | Information Gain = 0.025612122980204974 | Split IF X[6] < 0.526 THEN left O/W right
#                                                                                 -> LEAF | Label Counts = 0.0->3 | Pred Probs = [1. 0.]
#                                                                 -> NODE | Information Gain = 0.8112781244591328 | Split IF X[0] < 2.25 THEN left O/W right
#                                                                                 -> LEAF | Label Counts = 1.0->1 | Pred Probs = [0. 1.]
#                                                 -> NODE | Information Gain = 0.12414133222412968 | Split IF X[7] < 26.0 THEN left O/W right
#                                                                                 -> LEAF | Label Counts = 0.0->1 | Pred Probs = [1. 0.]
#                                                                 -> NODE | Information Gain = 0.0 | Split IF X[0] < 1.0 THEN left O/W right
#                                                                                 -> LEAF | Label Counts = 0.0->15 | Pred Probs = [1. 0.]
#                 -> NODE | Information Gain = 0.057762239697639384 | Split IF X[5] < 25.25 THEN left O/W right
#                                                                                 -> LEAF | Label Counts = 0.0->14, 1.0->3 | Pred Probs = [0.82352941 0.17647059]
#                                                                 -> NODE | Information Gain = 0.05092850928102721 | Split IF X[0] < 1.0 THEN left O/W right
#                                                                                 -> LEAF | Label Counts = 0.0->62, 1.0->1 | Pred Probs = [0.98412698 0.01587302]
#                                                 -> NODE | Information Gain = 0.04956471109020155 | Split IF X[3] < 32.0 THEN left O/W right
#                                                                                 -> LEAF | Label Counts = 0.0->8, 1.0->6 | Pred Probs = [0.57142857 0.42857143]
#                                                                 -> NODE | Information Gain = 0.13892706429224078 | Split IF X[2] < 66.0 THEN left O/W right
#                                                                                 -> LEAF | Label Counts = 0.0->14, 1.0->1 | Pred Probs = [0.93333333 0.06666667]
#                                 -> NODE | Information Gain = 0.05463941400360395 | Split IF X[7] < 27.0 THEN left O/W right
#                                                                                 -> LEAF | Label Counts = 0.0->34, 1.0->6 | Pred Probs = [0.85 0.15]
#                                                                 -> NODE | Information Gain = 0.03376254165892534 | Split IF X[6] < 0.60775 THEN left O/W right
#                                                                                 -> LEAF | Label Counts = 0.0->9, 1.0->5 | Pred Probs = [0.64285714 0.35714286]
#                                                 -> NODE | Information Gain = 0.03851534321370598 | Split IF X[1] < 100.0 THEN left O/W right
#                                                                                 -> LEAF | Label Counts = 0.0->15, 1.0->2 | Pred Probs = [0.88235294 0.11764706]
#                                                                 -> NODE | Information Gain = 0.10247112299316519 | Split IF X[6] < 0.238 THEN left O/W right
#                                                                                 -> LEAF | Label Counts = 0.0->24, 1.0->26 | Pred Probs = [0.48 0.52]
# -> NODE | Information Gain = 0.122424395661904 | Split IF X[1] < 117.5 THEN left O/W right
#                                                                 -> LEAF | Label Counts = 0.0->11 | Pred Probs = [1. 0.]
#                                                 -> NODE | Information Gain = 0.08879818204521883 | Split IF X[7] < 22.0 THEN left O/W right
#                                                                                 -> LEAF | Label Counts = 0.0->20, 1.0->3 | Pred Probs = [0.86956522 0.13043478]
#                                                                 -> NODE | Information Gain = 0.10790822401670441 | Split IF X[5] < 26.0 THEN left O/W right
#                                                                                 -> LEAF | Label Counts = 0.0->12, 1.0->11 | Pred Probs = [0.52173913 0.47826087]
#                                 -> NODE | Information Gain = 0.04558424833129382 | Split IF X[5] < 28.9 THEN left O/W right
#                                                                                 -> LEAF | Label Counts = 0.0->40, 1.0->20 | Pred Probs = [0.66666667 0.33333333]
#                                                                 -> NODE | Information Gain = 0.03933357902343959 | Split IF X[7] < 29.0 THEN left O/W right
#                                                                                 -> LEAF | Label Counts = 0.0->30, 1.0->39 | Pred Probs = [0.43478261 0.56521739]
#                                                 -> NODE | Information Gain = 0.04640798731826412 | Split IF X[7] < 42.25 THEN left O/W right
#                                                                                 -> LEAF | Label Counts = 0.0->7, 1.0->4 | Pred Probs = [0.63636364 0.36363636]
#                                                                 -> NODE | Information Gain = 0.1739374677717631 | Split IF X[6] < 0.214 THEN left O/W right
#                                                                                 -> LEAF | Label Counts = 0.0->4, 1.0->28 | Pred Probs = [0.125 0.875]
#                 -> NODE | Information Gain = 0.08427677035761305 | Split IF X[1] < 161.0 THEN left O/W right
#                                                                                 -> LEAF | Label Counts = 1.0->11 | Pred Probs = [0. 1.]
#                                                                 -> NODE | Information Gain = 0.06848454350380173 | Split IF X[2] < 66.5 THEN left O/W right
#                                                                                 -> LEAF | Label Counts = 0.0->6, 1.0->25 | Pred Probs = [0.19354839 0.80645161]
#                                                 -> NODE | Information Gain = 0.05137932188409822 | Split IF X[7] < 38.0 THEN left O/W right
#                                                                                 -> LEAF | Label Counts = 1.0->4 | Pred Probs = [0. 1.]
#                                                                 -> NODE | Information Gain = 0.0 | Split IF X[0] < 5.5 THEN left O/W right
#                                                                                 -> LEAF | Label Counts = 1.0->12 | Pred Probs = [0. 1.]
#                                 -> NODE | Information Gain = 0.053719620658030154 | Split IF X[7] < 48.5 THEN left O/W right
#                                                                                 -> LEAF | Label Counts = 0.0->5, 1.0->2 | Pred Probs = [0.71428571 0.28571429]
#                                                                 -> NODE | Information Gain = 0.3958156020033583 | Split IF X[2] < 89.5 THEN left O/W right
#                                                                                 -> LEAF | Label Counts = 1.0->3 | Pred Probs = [0. 1.]
#                                                 -> NODE | Information Gain = 0.07310400793180982 | Split IF X[1] < 177.5 THEN left O/W right
#                                                                                 -> LEAF | Label Counts = 1.0->5 | Pred Probs = [0. 1.]
#                                                                 -> NODE | Information Gain = 0.23645279766002802 | Split IF X[2] < 77.0 THEN left O/W right
#                                                                                 -> LEAF | Label Counts = 0.0->2, 1.0->3 | Pred Probs = [0.4 0.6]

# %%
# Feature importance
plt.bar(range(len(opt_tree_model.feature_importances)), 
        list(opt_tree_model.feature_importances.values()), tick_label=diabetes.feature_names)
plt.xticks(rotation=90)
plt.title("Feature Importance")
plt.xlabel("Feature")
plt.ylabel("Feature Importance")
plt.show()

# %% [markdown]
# # Random Forest Examples

# %% [markdown]
# ## Training on Iris Dataset

# %%
iris = datasets.load_iris()

X = np.array(iris.data)
Y = np.array(iris.target)
iris_feature_names = iris.feature_names

X_train, X_test, Y_train, Y_test = model_selection.train_test_split(X, Y, test_size=0.25, random_state=0)
print("Train Shape:", X_train.shape)
print("Train Shape:", X_test.shape)
# Out:
# Train Shape: (112, 4)
# Train Shape: (38, 4)

# %%
# Building random forest model
rf_model = RandomForestClassifier(n_base_learner=50, numb_of_features_splitting="sqrt")
rf_model.train(X_train, Y_train)

# %%
# Performans increases when compared to the basic DecisionTree
train_preds = rf_model.predict(X_set=X_train)
print("TRAIN PERFORMANCE")
print("Train size", len(Y_train))
print("True preds", sum(train_preds == Y_train))
print("Accuracy", sum(train_preds == Y_train) / len(Y_train))

test_preds = rf_model.predict(X_set=X_test)
print("TEST PERFORMANCE")
print("Test size", len(Y_test))
print("True preds", sum(test_preds == Y_test))
print("Accuracy", sum(test_preds == Y_test) / len(Y_test))
# Out:
# TRAIN PERFORMANCE
# Train size 112
# True preds 112
# Accuracy 1.0
# TEST PERFORMANCE
# Test size 38
# True preds 37
# Accuracy 0.9736842105263158

# %% [markdown]
# ## Training on Breast Cancer Dataset

# %%
# Load data
data = datasets.load_breast_cancer()
X = data.data
Y = data.target
breast_cancer_feature_names = data.feature_names

X_train, X_test, Y_train, Y_test = model_selection.train_test_split(X, Y, test_size=0.2, random_state=0)
print("Train Shape:", X_train.shape)
print("Train Shape:", X_test.shape)
# Out:
# Train Shape: (455, 30)
# Train Shape: (114, 30)

# %%
# Building random forest model
rf_model_2 = RandomForestClassifier(n_base_learner=100, 
                                    max_depth=4, min_samples_leaf=5, min_information_gain=0.05)
rf_model_2.train(X_train, Y_train)

# %%
# Performans increases when compared to the basic DecisionTree
train_preds = rf_model_2.predict(X_set=X_train)
print("TRAIN PERFORMANCE")
print("Train size", len(Y_train))
print("True preds", sum(train_preds == Y_train))
print("Accuracy", sum(train_preds == Y_train) / len(Y_train))

test_preds = rf_model_2.predict(X_set=X_test)
print("TEST PERFORMANCE")
print("Test size", len(Y_test))
print("True preds", sum(test_preds == Y_test))
print("Accuracy", sum(test_preds == Y_test) / len(Y_test))
# Out:
# TRAIN PERFORMANCE
# Train size 455
# True preds 448
# Accuracy 0.9846153846153847
# TEST PERFORMANCE
# Test size 114
# True preds 111
# Accuracy 0.9736842105263158

# %% [markdown]
# ## Training on Diabetes Data (from OpenML)

# %%
diabetes = datasets.fetch_openml(name="diabetes", as_frame=False)

# %%
diabetes_features = np.array(diabetes.data)
print(diabetes_features.shape)
diabetes_labels = np.array([y=="tested_positive" for y in diabetes.target]).astype(int)
print(diabetes_labels.shape)

X_train, X_test, Y_train, Y_test = model_selection.train_test_split(diabetes_features, diabetes_labels, test_size=0.2, random_state=0)
# Out:
# (768, 8)
# (768,)

# %%
rf_model_3 = RandomForestClassifier(n_base_learner=200, numb_of_features_splitting=None,
                                     max_depth=5, min_samples_leaf=1)
rf_model_3.train(X_train, Y_train)

# %%
# Performance increases when compared to basic decision tree
train_preds = rf_model_3.predict(X_set=X_train)
print("TRAIN PERFORMANCE")
print("Train size", len(Y_train))
print("True preds", sum(train_preds == Y_train))
print("Accuracy", sum(train_preds == Y_train) / len(Y_train))

test_preds = rf_model_3.predict(X_set=X_test)
print("TEST PERFORMANCE")
print("Test size", len(Y_test))
print("True preds", sum(test_preds == Y_test))
print("Accuracy", sum(test_preds == Y_test) / len(Y_test))
# Out:
# TRAIN PERFORMANCE
# Train size 614
# True preds 510
# Accuracy 0.8306188925081434
# TEST PERFORMANCE
# Test size 154
# True preds 123
# Accuracy 0.7987012987012987

# %%
# Feature importance of RandomForest Model
plt.bar(range(len(rf_model_3.feature_importances)), 
        list(rf_model_3.feature_importances), tick_label=diabetes.feature_names)
plt.xticks(rotation=90)
plt.title("Feature Importance")
plt.xlabel("Feature")
plt.ylabel("Feature Importance")
plt.show()

# %% [markdown]
# # AdaBoost Examples

# %% [markdown]
# ## Training on Iris Dataset

# %%
iris = datasets.load_iris()

X = np.array(iris.data)
Y = np.array(iris.target)

X_train, X_test, y_train, y_test = model_selection.train_test_split(X, Y, test_size=0.2, random_state=0)

model = AdaBoostClassifier(n_base_learner=50)
model.train(X_train, y_train)

train_accuracy = sum(model.predict(X=X_train) == y_train) / len(y_train)
test_accuracy = sum(model.predict(X=X_test) == y_test) / len(y_test)
print("Our Model Performance")
print("Train Accuracy: ", train_accuracy)
print("Test Accuracy: ", test_accuracy)
# Out:
# Our Model Performance
# Train Accuracy:  0.95
# Test Accuracy:  1.0

# %%
iris = datasets.load_iris()

X = np.array(iris.data)
Y = np.array(iris.target)

X_train, X_test, y_train, y_test = model_selection.train_test_split(X, Y, test_size=0.2, random_state=0)

model = sklearn.ensemble.AdaBoostClassifier(n_estimators=50)
model.fit(X_train, y_train)

train_accuracy = sum(model.predict(X=X_train) == y_train) / len(y_train)
test_accuracy = sum(model.predict(X=X_test) == y_test) / len(y_test)
print("Sklearn Model Performance")
print("Train Accuracy: ", train_accuracy)
print("Test Accuracy: ", test_accuracy)
# Out:
# Sklearn Model Performance
# Train Accuracy:  1.0
# Test Accuracy:  0.9666666666666667

# %% [markdown]
# ## Training on Breast Cancer Dataset

# %%
data = datasets.load_breast_cancer()

X = np.array(data.data)
Y = np.array(data.target)

X_train, X_test, y_train, y_test = model_selection.train_test_split(X, Y, test_size=0.2, random_state=0)

model = AdaBoostClassifier(n_base_learner=50)
model.train(X_train, y_train)

train_accuracy = sum(model.predict(X=X_train) == y_train) / len(y_train)
test_accuracy = sum(model.predict(X=X_test) == y_test) / len(y_test)
print("Our Model Performance")
print("Train Accuracy: ", train_accuracy)
print("Test Accuracy: ", test_accuracy)
# Out:
# Our Model Performance
# Train Accuracy:  0.9604395604395605
# Test Accuracy:  0.956140350877193

# %%
data = datasets.load_breast_cancer()

X = np.array(data.data)
Y = np.array(data.target)

X_train, X_test, y_train, y_test = model_selection.train_test_split(X, Y, test_size=0.2, random_state=0)

model = sklearn.ensemble.AdaBoostClassifier(n_estimators=50)
model.fit(X_train, y_train)

train_accuracy = sum(model.predict(X=X_train) == y_train) / len(y_train)
test_accuracy = sum(model.predict(X=X_test) == y_test) / len(y_test)
print("Sklearn Model Performance")
print("Train Accuracy: ", train_accuracy)
print("Test Accuracy: ", test_accuracy)
# Out:
# Sklearn Model Performance
# Train Accuracy:  1.0
# Test Accuracy:  0.9736842105263158

# %% [markdown]
# ## Training on Diabetes Data (from OpenML)

# %%
diabetes = datasets.fetch_openml(name="diabetes", as_frame=False)
diabetes_features = np.array(diabetes.data)
print(diabetes_features.shape)
diabetes_labels = np.array([y=="tested_positive" for y in diabetes.target]).astype(int)
print(diabetes_labels.shape)

X_train, X_test, y_train, y_test = model_selection.train_test_split(diabetes_features, diabetes_labels, test_size=0.2, random_state=0)
# Out:
# (768, 8)
# (768,)
# c:\Users\cheekish\Desktop\ML\ml\Lib\site-packages\sklearn\datasets\_openml.py:323: UserWarning: Multiple active versions of the dataset matching the name diabetes exist. Versions may be fundamentally different, returning version 1. Available versions:
# - version 1, status: active
#   url: https://www.openml.org/search?type=data&id=37
# - version 5, status: active
#   url: https://www.openml.org/search?type=data&id=42608
#
#   warn(warning_msg)

# %%
model = AdaBoostClassifier(n_base_learner=50)
model.train(X_train, y_train)

train_accuracy = sum(model.predict(X=X_train) == y_train) / len(y_train)
test_accuracy = sum(model.predict(X=X_test) == y_test) / len(y_test)
print("Our Model Performance")
print("Train Accuracy: ", train_accuracy)
print("Test Accuracy: ", test_accuracy)
# Out:
# Our Model Performance
# Train Accuracy:  0.7638436482084691
# Test Accuracy:  0.7792207792207793

# %%
model = sklearn.ensemble.AdaBoostClassifier(n_estimators=50)
model.fit(X_train, y_train)

train_accuracy = sum(model.predict(X=X_train) == y_train) / len(y_train)
test_accuracy = sum(model.predict(X=X_test) == y_test) / len(y_test)
print("Sklearn Model Performance")
print("Train Accuracy: ", train_accuracy)
print("Test Accuracy: ", test_accuracy)
# Out:
# Sklearn Model Performance
# Train Accuracy:  0.7899022801302932
# Test Accuracy:  0.7857142857142857

# %% [markdown]
# ## Some Simulations for Understanding the # of Base Learners in AdaBoost

# %%
data = datasets.load_breast_cancer()

X = np.array(data.data)
Y = np.array(data.target)

X_train, X_test, y_train, y_test = model_selection.train_test_split(X, Y, test_size=0.2, random_state=0)

# model = AdaBoostClassifier(n_base_learner=10)
# model.train(X_train, y_train)

train_accuracy_list = []
test_accuracy_list = []
for n_base_learner in range(1, 150, 3):
    model = AdaBoostClassifier(n_base_learner)
    model.train(X_train, y_train)
    train_accuracy_list.append(sum(model.predict(X=X_train) == y_train) / len(y_train))
    test_accuracy_list.append(sum(model.predict(X=X_test) == y_test) / len(y_test))

plt.plot(list(range(1, 150, 3)), train_accuracy_list, color='red', label='train')
plt.plot(list(range(1, 150, 3)), test_accuracy_list, color='green', label='test')
plt.title("Our AdaBoostClassifier Performance")
plt.xlabel('# of Base Learner')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
train_accuracy_list = []
test_accuracy_list = []
n_estimaters_list = []
for n_base_learner in range(1, 150, 3):
    model = sklearn.ensemble.AdaBoostClassifier(n_estimators=n_base_learner, learning_rate=0.2, random_state=0)
    model.fit(X_train, y_train)
    train_accuracy_list.append(sum(model.predict(X_train) == y_train) / len(y_train))
    test_accuracy_list.append(sum(model.predict(X_test) == y_test) / len(y_test))
    n_estimaters_list.append(len(model.estimators_))

plt.plot(list(range(1, 150, 3)), train_accuracy_list, color='red', label='train')
plt.plot(list(range(1, 150, 3)), test_accuracy_list, color='green', label='test')
plt.title("Sklearn AdaBoostClassifier Performance")
plt.xlabel('# of Base Learner')
plt.ylabel('Accuracy')
plt.legend()
plt.show()
