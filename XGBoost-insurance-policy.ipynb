# %% [markdown]
# <br>
# <section style="font-family:Times New Roman"><br>
#     <strong style= "font-weight: bold; color:#0e1a40; font-size:35px;"><i>LGBM | Optuna | Insurance Policy | Py</i></strong><br><br>
#     <b style= "font-weight: bold; color:#000000; font-size:20px;"> By: <i>Kheirallah Samaha</i></b><br><br>
#     <b style= "font-weight: bold; color:#000000; font-size:17px;"> Date: Dec-03-2024</b>
# </section>

# %% [markdown]
# **Dataset Description:**
# <br>
# The dataset for this competition (both train and test) was generated from a deep learning model trained on the Insurance Premium Prediction dataset. Feature distributions are close to, but not exactly the same, as the original. Feel free to use the original dataset as part of this competition, both to explore differences as well as to see whether incorporating the original in training improves model performance.
# <br>
# <br>
# **Files:**
# <br>
# <br>
# **train.csv -**  the training dataset; Premium Amount is the continuous target.
# **test.csv -** the test dataset; your objective is to predict target Premium Amount for each row.
# **sample_submission.csv -** a sample submission file in the correct format.

# %% [markdown]
# ## Import libraries

# %%
import warnings
import matplotlib.pyplot as plt
import numpy as np
import optuna
import pandas as pd
import seaborn as sns
from datetime import datetime
from xgboost import XGBRegressor
import xgboost as xgb
from sklearn import metrics
from sklearn.metrics import mean_squared_log_error
from sklearn.model_selection import (
    KFold,
    RandomizedSearchCV,
    StratifiedKFold,
    RepeatedKFold,
    cross_val_score,
    train_test_split,
)

import shap


def rmsle(y_true, y_pred):
    return np.sqrt(mean_squared_log_error(y_true, y_pred))

warnings.filterwarnings("ignore", category=FutureWarning)
plt.style.use("fast")

# %% [markdown]
# ## Load the Datasets

# %%
train_df_imp = pd.read_csv("train.csv")
test_df_imp = pd.read_csv("test.csv")
sample_submission = pd.read_csv("submission.csv")

# %%
train_df_imp.head()
# Out:
#    id   Age  Gender  Annual Income Marital Status  Number of Dependents  \
# 0   0  19.0  Female        10049.0        Married                   1.0
# 1   1  39.0  Female        31678.0       Divorced                   3.0
# 2   2  23.0    Male        25602.0       Divorced                   3.0
# 3   3  21.0    Male       141855.0        Married                   2.0
# 4   4  21.0    Male        39651.0         Single                   1.0
#
#   Education Level     Occupation  Health Score  Location  ... Previous Claims  \
# 0      Bachelor's  Self-Employed     22.598761     Urban  ...             2.0
# 1        Master's            NaN     15.569731     Rural  ...             1.0
# 2     High School  Self-Employed     47.177549  Suburban  ...             1.0
# 3      Bachelor's            NaN     10.938144     Rural  ...             1.0
# 4      Bachelor's  Self-Employed     20.376094     Rural  ...             0.0
#
#    Vehicle Age  Credit Score  Insurance Duration           Policy Start Date  \
# 0         17.0         372.0                 5.0  2023-12-23 15:21:39.134960
# 1         12.0         694.0                 2.0  2023-06-12 15:21:39.111551
# 2         14.0           NaN                 3.0  2023-09-30 15:21:39.221386
# 3          0.0         367.0                 1.0  2024-06-12 15:21:39.226954
# 4          8.0         598.0                 4.0  2021-12-01 15:21:39.252145
#
#   Customer Feedback Smoking Status Exercise Frequency Property Type  \
# 0              Poor             No             Weekly         House
# 1           Average            Yes            Monthly         House
# 2              Good            Yes             Weekly         House
# 3              Poor            Yes              Daily     Apartment
# 4              Poor            Yes             Weekly         House
#
#   Premium Amount
# 0         2869.0
# 1         1483.0
# 2          567.0
# 3          765.0
# 4         2022.0
#
# [5 rows x 21 columns]

# %%
train_df_imp.nunique().sort_values()
# Out:
# Gender                        2
# Smoking Status                2
# Policy Type                   3
# Marital Status                3
# Occupation                    3
# Location                      3
# Property Type                 3
# Customer Feedback             3
# Exercise Frequency            4
# Education Level               4
# Number of Dependents          5
# Insurance Duration            9
# Previous Claims              10
# Vehicle Age                  20
# Age                          47
# Credit Score                550
# Premium Amount             4794
# Annual Income             88593
# Policy Start Date        167381
# Health Score             532657
# id                      1200000
# dtype: int64

# %%
train_df_imp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1200000 entries, 0 to 1199999
# Data columns (total 21 columns):
#  #   Column                Non-Null Count    Dtype
# ---  ------                --------------    -----
#  0   id                    1200000 non-null  int64
#  1   Age                   1181295 non-null  float64
#  2   Gender                1200000 non-null  object
#  3   Annual Income         1155051 non-null  float64
#  4   Marital Status        1181471 non-null  object
#  5   Number of Dependents  1090328 non-null  float64
#  6   Education Level       1200000 non-null  object
#  7   Occupation            841925 non-null   object
#  8   Health Score          1125924 non-null  float64
#  9   Location              1200000 non-null  object
#  10  Policy Type           1200000 non-null  object
#  11  Previous Claims       835971 non-null   float64
#  12  Vehicle Age           1199994 non-null  float64
#  13  Credit Score          1062118 non-null  float64
#  14  Insurance Duration    1199999 non-null  float64
#  15  Policy Start Date     1200000 non-null  object
#  16  Customer Feedback     1122176 non-null  object
#  17  Smoking Status        1200000 non-null  object
#  18  Exercise Frequency    1200000 non-null  object
#  19  Property Type         1200000 non-null  object
#  20  Premium Amount        1200000 non-null  float64
# dtypes: float64(9), int64(1), object(11)
# memory usage: 192.3+ MB

# %%
def exrtact_date(df):
    df.columns = df.columns.str.replace(" ", "_")
    df = df.drop("id", axis="columns")
    df["Policy_Start_Date"] = pd.to_datetime(df["Policy_Start_Date"])
    df["Year"] = df["Policy_Start_Date"].dt.year.astype("category")
    df["Month"] = df["Policy_Start_Date"].dt.month.astype("category")
    df["Day"] = df["Policy_Start_Date"].dt.day.astype("category")
    df["Month_name"] = df["Policy_Start_Date"].dt.month_name()
    df["Day_of_week"] = df["Policy_Start_Date"].dt.day_name()
    df["Annual_Income_Health_Score_Ratio"] = df["Health_Score"] / df["Annual_Income"]
    df["Annual_Income_Age_Ratio"] = df["Annual_Income"] / df["Age"]
    df["Credit_Age"] = df["Credit_Score"] / df["Age"]
    df["Vehicle_Age_Insurance_Duration"] = df["Vehicle_Age"] / df["Insurance_Duration"]
    df["Policy_Start_Date"] = df["Policy_Start_Date"].dt.date
    return df

# %%
train_df = exrtact_date(train_df_imp)
test_df = exrtact_date(test_df_imp)

# %%
test_df.describe().round(2).style.format(precision=2).background_gradient(cmap="Blues")
# Out:
# <style type="text/css">
# #T_c0419_row0_col0, #T_c0419_row0_col1, #T_c0419_row0_col2, #T_c0419_row0_col3, #T_c0419_row0_col4, #T_c0419_row0_col5, #T_c0419_row0_col6, #T_c0419_row0_col7, #T_c0419_row0_col8, #T_c0419_row0_col9, #T_c0419_row0_col10, #T_c0419_row0_col11 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_c0419_row1_col0, #T_c0419_row1_col2, #T_c0419_row1_col3, #T_c0419_row1_col4, #T_c0419_row1_col5, #T_c0419_row1_col6, #T_c0419_row1_col7, #T_c0419_row1_col8, #T_c0419_row1_col9, #T_c0419_row1_col10, #T_c0419_row1_col11, #T_c0419_row2_col0, #T_c0419_row2_col2, #T_c0419_row2_col3, #T_c0419_row2_col4, #T_c0419_row2_col5, #T_c0419_row2_col6, #T_c0419_row2_col7, #T_c0419_row2_col8, #T_c0419_row2_col9, #T_c0419_row2_col10, #T_c0419_row2_col11, #T_c0419_row3_col0, #T_c0419_row3_col1, #T_c0419_row3_col2, #T_c0419_row3_col3, #T_c0419_row3_col4, #T_c0419_row3_col5, #T_c0419_row3_col6, #T_c0419_row3_col7, #T_c0419_row3_col8, #T_c0419_row3_col9, #T_c0419_row3_col10, #T_c0419_row3_col11, #T_c0419_row4_col0, #T_c0419_row4_col2, #T_c0419_row4_col3, #T_c0419_row4_col4, #T_c0419_row4_col5, #T_c0419_row4_col6, #T_c0419_row4_col7, #T_c0419_row4_col8, #T_c0419_row4_col9, #T_c0419_row4_col10, #T_c0419_row4_col11, #T_c0419_row5_col0, #T_c0419_row5_col2, #T_c0419_row5_col3, #T_c0419_row5_col4, #T_c0419_row5_col5, #T_c0419_row5_col6, #T_c0419_row5_col7, #T_c0419_row5_col8, #T_c0419_row5_col9, #T_c0419_row5_col10, #T_c0419_row5_col11, #T_c0419_row6_col0, #T_c0419_row6_col2, #T_c0419_row6_col3, #T_c0419_row6_col4, #T_c0419_row6_col5, #T_c0419_row6_col6, #T_c0419_row6_col7, #T_c0419_row6_col8, #T_c0419_row6_col9, #T_c0419_row6_col10, #T_c0419_row6_col11, #T_c0419_row7_col0, #T_c0419_row7_col2, #T_c0419_row7_col3, #T_c0419_row7_col4, #T_c0419_row7_col5, #T_c0419_row7_col6, #T_c0419_row7_col7, #T_c0419_row7_col8, #T_c0419_row7_col10, #T_c0419_row7_col11 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_c0419_row1_col1, #T_c0419_row2_col1 {
#   background-color: #eff6fc;
#   color: #000000;
# }
# #T_c0419_row4_col1, #T_c0419_row7_col9 {
#   background-color: #f5fafe;
#   color: #000000;
# }
# #T_c0419_row5_col1 {
#   background-color: #f2f7fd;
#   color: #000000;
# }
# #T_c0419_row6_col1 {
#   background-color: #ecf4fb;
#   color: #000000;
# }
# #T_c0419_row7_col1 {
#   background-color: #d1e2f3;
#   color: #000000;
# }
# </style>
# <table id="T_c0419">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c0419_level0_col0" class="col_heading level0 col0" >Age</th>
#       <th id="T_c0419_level0_col1" class="col_heading level0 col1" >Annual_Income</th>
#       <th id="T_c0419_level0_col2" class="col_heading level0 col2" >Number_of_Dependents</th>
#       <th id="T_c0419_level0_col3" class="col_heading level0 col3" >Health_Score</th>
#       <th id="T_c0419_level0_col4" class="col_heading level0 col4" >Previous_Claims</th>
#       <th id="T_c0419_level0_col5" class="col_heading level0 col5" >Vehicle_Age</th>
#       <th id="T_c0419_level0_col6" class="col_heading level0 col6" >Credit_Score</th>
#       <th id="T_c0419_level0_col7" class="col_heading level0 col7" >Insurance_Duration</th>
#       <th id="T_c0419_level0_col8" class="col_heading level0 col8" >Annual_Income_Health_Score_Ratio</th>
#       <th id="T_c0419_level0_col9" class="col_heading level0 col9" >Annual_Income_Age_Ratio</th>
#       <th id="T_c0419_level0_col10" class="col_heading level0 col10" >Credit_Age</th>
#       <th id="T_c0419_level0_col11" class="col_heading level0 col11" >Vehicle_Age_Insurance_Duration</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c0419_level0_row0" class="row_heading level0 row0" >count</th>
#       <td id="T_c0419_row0_col0" class="data row0 col0" >787511.00</td>
#       <td id="T_c0419_row0_col1" class="data row0 col1" >770140.00</td>
#       <td id="T_c0419_row0_col2" class="data row0 col2" >726870.00</td>
#       <td id="T_c0419_row0_col3" class="data row0 col3" >750551.00</td>
#       <td id="T_c0419_row0_col4" class="data row0 col4" >557198.00</td>
#       <td id="T_c0419_row0_col5" class="data row0 col5" >799997.00</td>
#       <td id="T_c0419_row0_col6" class="data row0 col6" >708549.00</td>
#       <td id="T_c0419_row0_col7" class="data row0 col7" >799998.00</td>
#       <td id="T_c0419_row0_col8" class="data row0 col8" >722335.00</td>
#       <td id="T_c0419_row0_col9" class="data row0 col9" >758132.00</td>
#       <td id="T_c0419_row0_col10" class="data row0 col10" >697541.00</td>
#       <td id="T_c0419_row0_col11" class="data row0 col11" >799995.00</td>
#     </tr>
#     <tr>
#       <th id="T_c0419_level0_row1" class="row_heading level0 row1" >mean</th>
#       <td id="T_c0419_row1_col0" class="data row1 col0" >41.14</td>
#       <td id="T_c0419_row1_col1" class="data row1 col1" >32803.87</td>
#       <td id="T_c0419_row1_col2" class="data row1 col2" >2.01</td>
#       <td id="T_c0419_row1_col3" class="data row1 col3" >25.61</td>
#       <td id="T_c0419_row1_col4" class="data row1 col4" >1.00</td>
#       <td id="T_c0419_row1_col5" class="data row1 col5" >9.57</td>
#       <td id="T_c0419_row1_col6" class="data row1 col6" >592.90</td>
#       <td id="T_c0419_row1_col7" class="data row1 col7" >5.02</td>
#       <td id="T_c0419_row1_col8" class="data row1 col8" >0.01</td>
#       <td id="T_c0419_row1_col9" class="data row1 col9" >906.46</td>
#       <td id="T_c0419_row1_col10" class="data row1 col10" >16.38</td>
#       <td id="T_c0419_row1_col11" class="data row1 col11" >3.00</td>
#     </tr>
#     <tr>
#       <th id="T_c0419_level0_row2" class="row_heading level0 row2" >std</th>
#       <td id="T_c0419_row2_col0" class="data row2 col0" >13.54</td>
#       <td id="T_c0419_row2_col1" class="data row2 col1" >32201.06</td>
#       <td id="T_c0419_row2_col2" class="data row2 col2" >1.42</td>
#       <td id="T_c0419_row2_col3" class="data row2 col3" >12.21</td>
#       <td id="T_c0419_row2_col4" class="data row2 col4" >0.98</td>
#       <td id="T_c0419_row2_col5" class="data row2 col5" >5.77</td>
#       <td id="T_c0419_row2_col6" class="data row2 col6" >150.12</td>
#       <td id="T_c0419_row2_col7" class="data row2 col7" >2.59</td>
#       <td id="T_c0419_row2_col8" class="data row2 col8" >0.07</td>
#       <td id="T_c0419_row2_col9" class="data row2 col9" >1016.71</td>
#       <td id="T_c0419_row2_col10" class="data row2 col10" >7.73</td>
#       <td id="T_c0419_row2_col11" class="data row2 col11" >3.52</td>
#     </tr>
#     <tr>
#       <th id="T_c0419_level0_row3" class="row_heading level0 row3" >min</th>
#       <td id="T_c0419_row3_col0" class="data row3 col0" >18.00</td>
#       <td id="T_c0419_row3_col1" class="data row3 col1" >2.00</td>
#       <td id="T_c0419_row3_col2" class="data row3 col2" >0.00</td>
#       <td id="T_c0419_row3_col3" class="data row3 col3" >1.65</td>
#       <td id="T_c0419_row3_col4" class="data row3 col4" >0.00</td>
#       <td id="T_c0419_row3_col5" class="data row3 col5" >0.00</td>
#       <td id="T_c0419_row3_col6" class="data row3 col6" >300.00</td>
#       <td id="T_c0419_row3_col7" class="data row3 col7" >1.00</td>
#       <td id="T_c0419_row3_col8" class="data row3 col8" >0.00</td>
#       <td id="T_c0419_row3_col9" class="data row3 col9" >0.04</td>
#       <td id="T_c0419_row3_col10" class="data row3 col10" >4.69</td>
#       <td id="T_c0419_row3_col11" class="data row3 col11" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_c0419_level0_row4" class="row_heading level0 row4" >25%</th>
#       <td id="T_c0419_row4_col0" class="data row4 col0" >30.00</td>
#       <td id="T_c0419_row4_col1" class="data row4 col1" >8048.00</td>
#       <td id="T_c0419_row4_col2" class="data row4 col2" >1.00</td>
#       <td id="T_c0419_row4_col3" class="data row4 col3" >15.92</td>
#       <td id="T_c0419_row4_col4" class="data row4 col4" >0.00</td>
#       <td id="T_c0419_row4_col5" class="data row4 col5" >5.00</td>
#       <td id="T_c0419_row4_col6" class="data row4 col6" >468.00</td>
#       <td id="T_c0419_row4_col7" class="data row4 col7" >3.00</td>
#       <td id="T_c0419_row4_col8" class="data row4 col8" >0.00</td>
#       <td id="T_c0419_row4_col9" class="data row4 col9" >206.24</td>

# %%
train_df.describe().round(2).style.format(precision=2).background_gradient(cmap="Blues")
# Out:
# <style type="text/css">
# #T_3eba2_row0_col0, #T_3eba2_row0_col1, #T_3eba2_row0_col2, #T_3eba2_row0_col3, #T_3eba2_row0_col4, #T_3eba2_row0_col5, #T_3eba2_row0_col6, #T_3eba2_row0_col7, #T_3eba2_row0_col8, #T_3eba2_row0_col9, #T_3eba2_row0_col10, #T_3eba2_row0_col11, #T_3eba2_row0_col12 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_3eba2_row1_col0, #T_3eba2_row1_col2, #T_3eba2_row1_col3, #T_3eba2_row1_col4, #T_3eba2_row1_col5, #T_3eba2_row1_col6, #T_3eba2_row1_col7, #T_3eba2_row1_col8, #T_3eba2_row1_col9, #T_3eba2_row1_col10, #T_3eba2_row1_col11, #T_3eba2_row1_col12, #T_3eba2_row2_col0, #T_3eba2_row2_col2, #T_3eba2_row2_col3, #T_3eba2_row2_col4, #T_3eba2_row2_col5, #T_3eba2_row2_col6, #T_3eba2_row2_col7, #T_3eba2_row2_col8, #T_3eba2_row2_col9, #T_3eba2_row2_col10, #T_3eba2_row2_col11, #T_3eba2_row2_col12, #T_3eba2_row3_col0, #T_3eba2_row3_col1, #T_3eba2_row3_col2, #T_3eba2_row3_col3, #T_3eba2_row3_col4, #T_3eba2_row3_col5, #T_3eba2_row3_col6, #T_3eba2_row3_col7, #T_3eba2_row3_col8, #T_3eba2_row3_col9, #T_3eba2_row3_col10, #T_3eba2_row3_col11, #T_3eba2_row3_col12, #T_3eba2_row4_col0, #T_3eba2_row4_col2, #T_3eba2_row4_col3, #T_3eba2_row4_col4, #T_3eba2_row4_col5, #T_3eba2_row4_col6, #T_3eba2_row4_col7, #T_3eba2_row4_col8, #T_3eba2_row4_col9, #T_3eba2_row4_col10, #T_3eba2_row4_col11, #T_3eba2_row4_col12, #T_3eba2_row5_col0, #T_3eba2_row5_col2, #T_3eba2_row5_col3, #T_3eba2_row5_col4, #T_3eba2_row5_col5, #T_3eba2_row5_col6, #T_3eba2_row5_col7, #T_3eba2_row5_col8, #T_3eba2_row5_col9, #T_3eba2_row5_col10, #T_3eba2_row5_col11, #T_3eba2_row5_col12, #T_3eba2_row6_col0, #T_3eba2_row6_col2, #T_3eba2_row6_col3, #T_3eba2_row6_col4, #T_3eba2_row6_col5, #T_3eba2_row6_col6, #T_3eba2_row6_col7, #T_3eba2_row6_col8, #T_3eba2_row6_col9, #T_3eba2_row6_col10, #T_3eba2_row6_col11, #T_3eba2_row6_col12, #T_3eba2_row7_col0, #T_3eba2_row7_col2, #T_3eba2_row7_col3, #T_3eba2_row7_col4, #T_3eba2_row7_col5, #T_3eba2_row7_col6, #T_3eba2_row7_col7, #T_3eba2_row7_col9, #T_3eba2_row7_col11, #T_3eba2_row7_col12 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_3eba2_row1_col1, #T_3eba2_row2_col1 {
#   background-color: #f2f7fd;
#   color: #000000;
# }
# #T_3eba2_row4_col1, #T_3eba2_row7_col8, #T_3eba2_row7_col10 {
#   background-color: #f6faff;
#   color: #000000;
# }
# #T_3eba2_row5_col1 {
#   background-color: #f3f8fe;
#   color: #000000;
# }
# #T_3eba2_row6_col1 {
#   background-color: #f0f6fd;
#   color: #000000;
# }
# #T_3eba2_row7_col1 {
#   background-color: #ddeaf7;
#   color: #000000;
# }
# </style>
# <table id="T_3eba2">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3eba2_level0_col0" class="col_heading level0 col0" >Age</th>
#       <th id="T_3eba2_level0_col1" class="col_heading level0 col1" >Annual_Income</th>
#       <th id="T_3eba2_level0_col2" class="col_heading level0 col2" >Number_of_Dependents</th>
#       <th id="T_3eba2_level0_col3" class="col_heading level0 col3" >Health_Score</th>
#       <th id="T_3eba2_level0_col4" class="col_heading level0 col4" >Previous_Claims</th>
#       <th id="T_3eba2_level0_col5" class="col_heading level0 col5" >Vehicle_Age</th>
#       <th id="T_3eba2_level0_col6" class="col_heading level0 col6" >Credit_Score</th>
#       <th id="T_3eba2_level0_col7" class="col_heading level0 col7" >Insurance_Duration</th>
#       <th id="T_3eba2_level0_col8" class="col_heading level0 col8" >Premium_Amount</th>
#       <th id="T_3eba2_level0_col9" class="col_heading level0 col9" >Annual_Income_Health_Score_Ratio</th>
#       <th id="T_3eba2_level0_col10" class="col_heading level0 col10" >Annual_Income_Age_Ratio</th>
#       <th id="T_3eba2_level0_col11" class="col_heading level0 col11" >Credit_Age</th>
#       <th id="T_3eba2_level0_col12" class="col_heading level0 col12" >Vehicle_Age_Insurance_Duration</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3eba2_level0_row0" class="row_heading level0 row0" >count</th>
#       <td id="T_3eba2_row0_col0" class="data row0 col0" >1181295.00</td>
#       <td id="T_3eba2_row0_col1" class="data row0 col1" >1155051.00</td>
#       <td id="T_3eba2_row0_col2" class="data row0 col2" >1090328.00</td>
#       <td id="T_3eba2_row0_col3" class="data row0 col3" >1125924.00</td>
#       <td id="T_3eba2_row0_col4" class="data row0 col4" >835971.00</td>
#       <td id="T_3eba2_row0_col5" class="data row0 col5" >1199994.00</td>
#       <td id="T_3eba2_row0_col6" class="data row0 col6" >1062118.00</td>
#       <td id="T_3eba2_row0_col7" class="data row0 col7" >1199999.00</td>
#       <td id="T_3eba2_row0_col8" class="data row0 col8" >1200000.00</td>
#       <td id="T_3eba2_row0_col9" class="data row0 col9" >1083363.00</td>
#       <td id="T_3eba2_row0_col10" class="data row0 col10" >1137086.00</td>
#       <td id="T_3eba2_row0_col11" class="data row0 col11" >1045562.00</td>
#       <td id="T_3eba2_row0_col12" class="data row0 col12" >1199993.00</td>
#     </tr>
#     <tr>
#       <th id="T_3eba2_level0_row1" class="row_heading level0 row1" >mean</th>
#       <td id="T_3eba2_row1_col0" class="data row1 col0" >41.15</td>
#       <td id="T_3eba2_row1_col1" class="data row1 col1" >32745.22</td>
#       <td id="T_3eba2_row1_col2" class="data row1 col2" >2.01</td>
#       <td id="T_3eba2_row1_col3" class="data row1 col3" >25.61</td>
#       <td id="T_3eba2_row1_col4" class="data row1 col4" >1.00</td>
#       <td id="T_3eba2_row1_col5" class="data row1 col5" >9.57</td>
#       <td id="T_3eba2_row1_col6" class="data row1 col6" >592.92</td>
#       <td id="T_3eba2_row1_col7" class="data row1 col7" >5.02</td>
#       <td id="T_3eba2_row1_col8" class="data row1 col8" >1102.54</td>
#       <td id="T_3eba2_row1_col9" class="data row1 col9" >0.01</td>
#       <td id="T_3eba2_row1_col10" class="data row1 col10" >904.40</td>
#       <td id="T_3eba2_row1_col11" class="data row1 col11" >16.38</td>
#       <td id="T_3eba2_row1_col12" class="data row1 col12" >3.00</td>
#     </tr>
#     <tr>
#       <th id="T_3eba2_level0_row2" class="row_heading level0 row2" >std</th>
#       <td id="T_3eba2_row2_col0" class="data row2 col0" >13.54</td>
#       <td id="T_3eba2_row2_col1" class="data row2 col1" >32179.51</td>
#       <td id="T_3eba2_row2_col2" class="data row2 col2" >1.42</td>
#       <td id="T_3eba2_row2_col3" class="data row2 col3" >12.20</td>
#       <td id="T_3eba2_row2_col4" class="data row2 col4" >0.98</td>
#       <td id="T_3eba2_row2_col5" class="data row2 col5" >5.78</td>
#       <td id="T_3eba2_row2_col6" class="data row2 col6" >149.98</td>
#       <td id="T_3eba2_row2_col7" class="data row2 col7" >2.59</td>
#       <td id="T_3eba2_row2_col8" class="data row2 col8" >865.00</td>
#       <td id="T_3eba2_row2_col9" class="data row2 col9" >0.08</td>
#       <td id="T_3eba2_row2_col10" class="data row2 col10" >1015.43</td>
#       <td id="T_3eba2_row2_col11" class="data row2 col11" >7.73</td>
#       <td id="T_3eba2_row2_col12" class="data row2 col12" >3.52</td>
#     </tr>
#     <tr>
#       <th id="T_3eba2_level0_row3" class="row_heading level0 row3" >min</th>
#       <td id="T_3eba2_row3_col0" class="data row3 col0" >18.00</td>
#       <td id="T_3eba2_row3_col1" class="data row3 col1" >1.00</td>
#       <td id="T_3eba2_row3_col2" class="data row3 col2" >0.00</td>
#       <td id="T_3eba2_row3_col3" class="data row3 col3" >2.01</td>
#       <td id="T_3eba2_row3_col4" class="data row3 col4" >0.00</td>
#       <td id="T_3eba2_row3_col5" class="data row3 col5" >0.00</td>
#       <td id="T_3eba2_row3_col6" class="data row3 col6" >300.00</td>
#       <td id="T_3eba2_row3_col7" class="data row3 col7" >1.00</td>
#       <td id="T_3eba2_row3_col8" class="data row3 col8" >20.00</td>
#       <td id="T_3eba2_row3_col9" class="data row3 col9" >0.00</td>
#       <td id="T_3eba2_row3_col10" class="data row3 col10" >0.03</td>
#       <td id="T_3eba2_row3_col11" class="data row3 col11" >4.69</td>
#       <td id="T_3eba2_row3_col12" class="data row3 col12" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_3eba2_level0_row4" class="row_heading level0 row4" >25%</th>
#       <td id="T_3eba2_row4_col0" class="data row4 col0" >30.00</td>
#       <td id="T_3eba2_row4_col1" class="data row4 col1" >800

# %%
num_vars = train_df.select_dtypes("float64").columns.to_list()
obj_vars = train_df.select_dtypes("object").columns.to_list()
test_num_vars = np.delete(num_vars, 8)

# %%
train_df[num_vars] = train_df[num_vars].fillna(train_df[num_vars].median())
train_df[obj_vars] = train_df[obj_vars].fillna("Missing")
test_df[test_num_vars] = test_df[test_num_vars].fillna(test_df[test_num_vars].median())
test_df[obj_vars] = test_df[obj_vars].fillna("Missing")

# %%
train_df[obj_vars] = train_df[obj_vars].astype("category")
test_df[obj_vars] = test_df[obj_vars].astype("category")

# %%
gender_color = dict({"Male": "#2986cc", "Female": "#c90076"})
marital_status_color = dict({"Divorced": "#91204e", "Married": "#0e8806", "Single": "#fe960e", "Missing": "gray"})
smoking_status_color = dict({"No": "#f17878", "Yes": "#875c7a"})

# %% [markdown]
# ## Describe

# %%
train_df.describe().round(2).style.format(precision=2).background_gradient(cmap="Blues")
# Out:
# <style type="text/css">
# #T_df7ac_row0_col0, #T_df7ac_row0_col1, #T_df7ac_row0_col2, #T_df7ac_row0_col3, #T_df7ac_row0_col4, #T_df7ac_row0_col5, #T_df7ac_row0_col6, #T_df7ac_row0_col7, #T_df7ac_row0_col8, #T_df7ac_row0_col9, #T_df7ac_row0_col10, #T_df7ac_row0_col11, #T_df7ac_row0_col12 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_df7ac_row1_col0, #T_df7ac_row1_col2, #T_df7ac_row1_col3, #T_df7ac_row1_col4, #T_df7ac_row1_col5, #T_df7ac_row1_col6, #T_df7ac_row1_col7, #T_df7ac_row1_col8, #T_df7ac_row1_col9, #T_df7ac_row1_col10, #T_df7ac_row1_col11, #T_df7ac_row1_col12, #T_df7ac_row2_col0, #T_df7ac_row2_col2, #T_df7ac_row2_col3, #T_df7ac_row2_col4, #T_df7ac_row2_col5, #T_df7ac_row2_col6, #T_df7ac_row2_col7, #T_df7ac_row2_col8, #T_df7ac_row2_col9, #T_df7ac_row2_col10, #T_df7ac_row2_col11, #T_df7ac_row2_col12, #T_df7ac_row3_col0, #T_df7ac_row3_col1, #T_df7ac_row3_col2, #T_df7ac_row3_col3, #T_df7ac_row3_col4, #T_df7ac_row3_col5, #T_df7ac_row3_col6, #T_df7ac_row3_col7, #T_df7ac_row3_col8, #T_df7ac_row3_col9, #T_df7ac_row3_col10, #T_df7ac_row3_col11, #T_df7ac_row3_col12, #T_df7ac_row4_col0, #T_df7ac_row4_col2, #T_df7ac_row4_col3, #T_df7ac_row4_col4, #T_df7ac_row4_col5, #T_df7ac_row4_col6, #T_df7ac_row4_col7, #T_df7ac_row4_col8, #T_df7ac_row4_col9, #T_df7ac_row4_col10, #T_df7ac_row4_col11, #T_df7ac_row4_col12, #T_df7ac_row5_col0, #T_df7ac_row5_col2, #T_df7ac_row5_col3, #T_df7ac_row5_col4, #T_df7ac_row5_col5, #T_df7ac_row5_col6, #T_df7ac_row5_col7, #T_df7ac_row5_col8, #T_df7ac_row5_col9, #T_df7ac_row5_col10, #T_df7ac_row5_col11, #T_df7ac_row5_col12, #T_df7ac_row6_col0, #T_df7ac_row6_col2, #T_df7ac_row6_col3, #T_df7ac_row6_col4, #T_df7ac_row6_col5, #T_df7ac_row6_col6, #T_df7ac_row6_col7, #T_df7ac_row6_col8, #T_df7ac_row6_col9, #T_df7ac_row6_col10, #T_df7ac_row6_col11, #T_df7ac_row6_col12, #T_df7ac_row7_col0, #T_df7ac_row7_col2, #T_df7ac_row7_col3, #T_df7ac_row7_col4, #T_df7ac_row7_col5, #T_df7ac_row7_col6, #T_df7ac_row7_col7, #T_df7ac_row7_col9, #T_df7ac_row7_col11, #T_df7ac_row7_col12 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_df7ac_row1_col1, #T_df7ac_row2_col1 {
#   background-color: #f2f8fd;
#   color: #000000;
# }
# #T_df7ac_row4_col1, #T_df7ac_row7_col8, #T_df7ac_row7_col10 {
#   background-color: #f6faff;
#   color: #000000;
# }
# #T_df7ac_row5_col1 {
#   background-color: #f3f8fe;
#   color: #000000;
# }
# #T_df7ac_row6_col1 {
#   background-color: #f0f6fd;
#   color: #000000;
# }
# #T_df7ac_row7_col1 {
#   background-color: #dfebf7;
#   color: #000000;
# }
# </style>
# <table id="T_df7ac">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_df7ac_level0_col0" class="col_heading level0 col0" >Age</th>
#       <th id="T_df7ac_level0_col1" class="col_heading level0 col1" >Annual_Income</th>
#       <th id="T_df7ac_level0_col2" class="col_heading level0 col2" >Number_of_Dependents</th>
#       <th id="T_df7ac_level0_col3" class="col_heading level0 col3" >Health_Score</th>
#       <th id="T_df7ac_level0_col4" class="col_heading level0 col4" >Previous_Claims</th>
#       <th id="T_df7ac_level0_col5" class="col_heading level0 col5" >Vehicle_Age</th>
#       <th id="T_df7ac_level0_col6" class="col_heading level0 col6" >Credit_Score</th>
#       <th id="T_df7ac_level0_col7" class="col_heading level0 col7" >Insurance_Duration</th>
#       <th id="T_df7ac_level0_col8" class="col_heading level0 col8" >Premium_Amount</th>
#       <th id="T_df7ac_level0_col9" class="col_heading level0 col9" >Annual_Income_Health_Score_Ratio</th>
#       <th id="T_df7ac_level0_col10" class="col_heading level0 col10" >Annual_Income_Age_Ratio</th>
#       <th id="T_df7ac_level0_col11" class="col_heading level0 col11" >Credit_Age</th>
#       <th id="T_df7ac_level0_col12" class="col_heading level0 col12" >Vehicle_Age_Insurance_Duration</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_df7ac_level0_row0" class="row_heading level0 row0" >count</th>
#       <td id="T_df7ac_row0_col0" class="data row0 col0" >1200000.00</td>
#       <td id="T_df7ac_row0_col1" class="data row0 col1" >1200000.00</td>
#       <td id="T_df7ac_row0_col2" class="data row0 col2" >1200000.00</td>
#       <td id="T_df7ac_row0_col3" class="data row0 col3" >1200000.00</td>
#       <td id="T_df7ac_row0_col4" class="data row0 col4" >1200000.00</td>
#       <td id="T_df7ac_row0_col5" class="data row0 col5" >1200000.00</td>
#       <td id="T_df7ac_row0_col6" class="data row0 col6" >1200000.00</td>
#       <td id="T_df7ac_row0_col7" class="data row0 col7" >1200000.00</td>
#       <td id="T_df7ac_row0_col8" class="data row0 col8" >1200000.00</td>
#       <td id="T_df7ac_row0_col9" class="data row0 col9" >1200000.00</td>
#       <td id="T_df7ac_row0_col10" class="data row0 col10" >1200000.00</td>
#       <td id="T_df7ac_row0_col11" class="data row0 col11" >1200000.00</td>
#       <td id="T_df7ac_row0_col12" class="data row0 col12" >1200000.00</td>
#     </tr>
#     <tr>
#       <th id="T_df7ac_level0_row1" class="row_heading level0 row1" >mean</th>
#       <td id="T_df7ac_row1_col0" class="data row1 col0" >41.14</td>
#       <td id="T_df7ac_row1_col1" class="data row1 col1" >32414.31</td>
#       <td id="T_df7ac_row1_col2" class="data row1 col2" >2.01</td>
#       <td id="T_df7ac_row1_col3" class="data row1 col3" >25.55</td>
#       <td id="T_df7ac_row1_col4" class="data row1 col4" >1.00</td>
#       <td id="T_df7ac_row1_col5" class="data row1 col5" >9.57</td>
#       <td id="T_df7ac_row1_col6" class="data row1 col6" >593.16</td>
#       <td id="T_df7ac_row1_col7" class="data row1 col7" >5.02</td>
#       <td id="T_df7ac_row1_col8" class="data row1 col8" >1102.54</td>
#       <td id="T_df7ac_row1_col9" class="data row1 col9" >0.01</td>
#       <td id="T_df7ac_row1_col10" class="data row1 col10" >887.47</td>
#       <td id="T_df7ac_row1_col11" class="data row1 col11" >16.13</td>
#       <td id="T_df7ac_row1_col12" class="data row1 col12" >3.00</td>
#     </tr>
#     <tr>
#       <th id="T_df7ac_level0_row2" class="row_heading level0 row2" >std</th>
#       <td id="T_df7ac_row2_col0" class="data row2 col0" >13.43</td>
#       <td id="T_df7ac_row2_col1" class="data row2 col1" >31615.60</td>
#       <td id="T_df7ac_row2_col2" class="data row2 col2" >1.35</td>
#       <td id="T_df7ac_row2_col3" class="data row2 col3" >11.82</td>
#       <td id="T_df7ac_row2_col4" class="data row2 col4" >0.82</td>
#       <td id="T_df7ac_row2_col5" class="data row2 col5" >5.78</td>
#       <td id="T_df7ac_row2_col6" class="data row2 col6" >141.10</td>
#       <td id="T_df7ac_row2_col7" class="data row2 col7" >2.59</td>
#       <td id="T_df7ac_row2_col8" class="data row2 col8" >865.00</td>
#       <td id="T_df7ac_row2_col9" class="data row2 col9" >0.07</td>
#       <td id="T_df7ac_row2_col10" class="data row2 col10" >991.07</td>
#       <td id="T_df7ac_row2_col11" class="data row2 col11" >7.25</td>
#       <td id="T_df7ac_row2_col12" class="data row2 col12" >3.52</td>
#     </tr>
#     <tr>
#       <th id="T_df7ac_level0_row3" class="row_heading level0 row3" >min</th>
#       <td id="T_df7ac_row3_col0" class="data row3 col0" >18.00</td>
#       <td id="T_df7ac_row3_col1" class="data row3 col1" >1.00</td>
#       <td id="T_df7ac_row3_col2" class="data row3 col2" >0.00</td>
#       <td id="T_df7ac_row3_col3" class="data row3 col3" >2.01</td>
#       <td id="T_df7ac_row3_col4" class="data row3 col4" >0.00</td>
#       <td id="T_df7ac_row3_col5" class="data row3 col5" >0.00</td>
#       <td id="T_df7ac_row3_col6" class="data row3 col6" >300.00</td>
#       <td id="T_df7ac_row3_col7" class="data row3 col7" >1.00</td>
#       <td id="T_df7ac_row3_col8" class="data row3 col8" >20.00</td>
#       <td id="T_df7ac_row3_col9" class="data row3 col9" >0.00</td>
#       <td id="T_df7ac_row3_col10" class="data row3 col10" >0.03</td>
#       <td id="T_df7ac_row3_col11" class="data row3 col11" >4.69</td>
#       <td id="T_df7ac_row3_col12" class="data row3 col12" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_df7ac_level0_row4" class="row_heading level0 row4" >25%</th>
#       <td id="T_df7ac_row4_col0" class="data row4 col0" >30.00</td>
#       <td id="T_df7ac_row4_col1" class="data row4 col1" >864

# %% [markdown]
# ### 2% Sample For EDA

# %%
df_sample_n = train_df.groupby("Premium_Amount").sample(frac=0.2, random_state= 8).reset_index(drop = True)

# %%
df_sample_n
# Out:
#          Age  Gender  Annual_Income Marital_Status  Number_of_Dependents  \
# 0       46.0    Male        46403.0        Married                   0.0
# 1       28.0    Male        27442.0        Married                   4.0
# 2       34.0  Female          758.0       Divorced                   3.0
# 3       30.0    Male         1313.0         Single                   2.0
# 4       36.0    Male        30443.0       Divorced                   4.0
# ...      ...     ...            ...            ...                   ...
# 239992  19.0  Female        55739.0         Single                   1.0
# 239993  24.0  Female        53868.0         Single                   1.0
# 239994  46.0  Female        23911.0       Divorced                   0.0
# 239995  42.0  Female        17604.0         Single                   3.0
# 239996  48.0    Male         2428.0         Single                   1.0
#
#        Education_Level     Occupation  Health_Score  Location    Policy_Type  \
# 0           Bachelor's  Self-Employed     14.121177     Urban  Comprehensive
# 1          High School        Missing     24.578648  Suburban          Basic
# 2             Master's        Missing     24.573389     Urban  Comprehensive
# 3          High School        Missing     44.929552     Rural        Premium
# 4           Bachelor's       Employed     28.788200     Rural  Comprehensive
# ...                ...            ...           ...       ...            ...
# 239992     High School     Unemployed     39.191166     Urban  Comprehensive
# 239993        Master's        Missing     31.255646     Urban        Premium
# 239994      Bachelor's     Unemployed     11.739787     Rural        Premium
# 239995      Bachelor's  Self-Employed     18.847191  Suburban          Basic
# 239996      Bachelor's       Employed     40.988798     Rural  Comprehensive
#
#         ...  Premium_Amount  Year  Month  Day Month_name Day_of_week  \
# 0       ...            20.0  2023      2   21   February     Tuesday
# 1       ...            20.0  2021      9   28  September     Tuesday
# 2       ...            20.0  2020     10   29    October    Thursday
# 3       ...            20.0  2022      3    5      March    Saturday
# 4       ...            20.0  2021      5    5        May   Wednesday
# ...     ...             ...   ...    ...  ...        ...         ...
# 239992  ...          4987.0  2022      3    6      March      Sunday
# 239993  ...          4988.0  2022      3   20      March      Sunday
# 239994  ...          4988.0  2021      6   20       June      Sunday
# 239995  ...          4988.0  2019      9   20  September      Friday
# 239996  ...          4988.0  2021      8   15     August      Sunday
#
#        Annual_Income_Health_Score_Ratio Annual_Income_Age_Ratio Credit_Age  \
# 0                              0.000304             1008.760870   9.000000
# 1                              0.001020              980.071429  14.407407
# 2                              0.032419               22.294118  20.470588
# 3                              0.034219               43.766667  19.766667
# 4                              0.000946              845.638889  14.750000
# ...                                 ...                     ...        ...
# 239992                         0.000703             2933.631579  15.947368
# 239993                         0.000580             2244.500000  12.625000
# 239994                         0.001020              581.425926  14.407407
# 239995                         0.001071              419.142857  18.214286
# 239996                         0.016882               50.583333  14.500000
#
#         Vehicle_Age_Insurance_Duration
# 0                             1.333333
# 1                             2.833333
# 2                             0.000000
# 3                            18.000000
# 4                             7.500000
# ...                                ...
# 239992                        2.000000
# 239993                        0.111111
# 239994                        2.666667
# 239995                        1.000000
# 239996                        2.200000
#
# [239997 rows x 29 columns]

# %% [markdown]
# ## Numerical Variables Distributions

# %%
fig = plt.figure(figsize=(10, 12))

for i, feature in enumerate(num_vars):
    ax = fig.add_subplot(7, 2, i + 1)
    sns.histplot(
        df_sample_n[feature],
        stat="percent",
        kde=True,
        bins=40,
        alpha=0.7,
        color="#ff9a00",
        line_kws={"lw": 1.5, "linestyle": "dashed"},
    ).lines[0].set_color("darkred")
    plt.tick_params(axis="both", labelsize=9)
    plt.ylabel("Percent", fontsize=9)
    plt.xlabel(feature, fontsize=9)


fig.tight_layout()
plt.show()

# %% [markdown]
# ### Target Variable Distribution

# %%
mean_premium_amount = train_df[["Premium_Amount"]].mean().squeeze()

fig, (ax1, ax2) = plt.subplots(2, figsize=(10, 4))

sns.histplot(data=train_df, x="Premium_Amount", color="#ff9a00", bins=40, alpha=0.7, lw=0.1, ax=ax1)

sns.boxplot(
    data=train_df,
    x="Premium_Amount",
    color="#ff9a00",
    linewidth=0.3,
    flierprops=dict(
        marker="o", markersize=4, markerfacecolor="darkred", markeredgecolor="darkred"
    ),
    boxprops=dict(alpha=0.7),
    ax=ax2,
)
ax2.set_title("")
ax2.set_xlabel("Premium Amount", fontsize=12)

ax1.set_title("Premium Amount Distribution", fontsize=12)
ax1.set_xlabel("")

ax1.axvline(x=mean_premium_amount, color="darkred", ls="--", lw=1.5)
ax1.text(
    mean_premium_amount + 50,
    90000,
    "Mean Premium Amount | " + str(mean_premium_amount.round(0)),
    fontsize=9,
    color="#000000",
)

plt.show()

# %% [markdown]
# ### Age Distribution

# %%
mean_age = train_df[["Age"]].mean().squeeze()

fig, (ax1, ax2) = plt.subplots(2, figsize=(10, 4))

sns.histplot(
    data=train_df, x="Age", color="#ff9a00", bins=40, alpha=0.8, lw=0.1, ax=ax1
)

sns.boxplot(
    data=train_df,
    x="Age",
    color="#ff9a00",
    linewidth=0.3,
    flierprops=dict(
        marker="o", markersize=4, markerfacecolor="#107dac", markeredgecolor="#107dac"
    ),
    boxprops=dict(alpha=0.7),
    ax=ax2,
)
ax2.set_title("")
ax2.set_xlabel("Age", fontsize=12)

ax1.set_title("Age Distribution", fontsize=12)
ax1.set_xlabel("")

ax1.axvline(x=mean_age, color="darkred", ls="--", lw=1.5)
ax1.text(
    mean_age - 7,
    50000,
    "Mean Age | " + str(mean_age.round(0)),
    fontsize=9,
    color="#000000",
)

plt.show()

# %% [markdown]
# ## Categorical Variables Distributions

# %%
fig = plt.figure(figsize=(10, 15))

for i, feature in enumerate(np.delete(obj_vars, 6)):
    ax = fig.add_subplot(6, 2, i + 1)
    df_temp = df_sample_n[feature].value_counts().nlargest(20).reset_index()
    sns.barplot(df_temp, y=feature, x="count", color="#ffc100", orient="h", alpha=0.9)
    ax.bar_label(
        ax.containers[0], label_type="center", padding=10, color="black", fontsize=8
    )
    [
        (lab.set_color("r"), lab.set_fontsize(10), lab.set_fontstyle('italic'))
        for lab in ax.get_yticklabels()
        if lab.get_text() == "Missing"
    ]
    ax.set_ylabel(feature, fontsize=10)
    ax.set_xlabel("Counts", fontsize=10)
    ax.tick_params(axis="both", labelsize=8)


fig.tight_layout()
plt.show()

# %% [markdown]
# ### All categorical variables are desperately Balanced!! I will take one of them for closer look! lets take Gender!

# %% [markdown]
# ## By Gender

# %%
def by_gender (x_var, sel_rotation = 0, sel_aspect = 2.5):
    gs = sns.catplot(
    data=df_sample_n,
    x= x_var,
    kind="count",
    hue="Gender",
    height=2.5,
    aspect=sel_aspect,
    sharey=False,
    #col_wrap=2,
    palette=gender_color,
    legend_out=False,
    legend="auto",
    width=0.5,
)
    for ax in gs.axes.ravel():
        for i in ax.containers:
            ax.bar_label(i, label_type="edge", fontsize=7, padding=3, rotation=sel_rotation)
            ax.set_xlabel("", fontsize=12)
            ax.set_ylabel("", fontsize=12)
            ax.tick_params(axis="both", labelsize=8)
            gs.set_titles(size=8)
            gs.legend.remove()
            [
        (lab.set_color("r"), lab.set_fontsize(10), lab.set_fontstyle('italic'))
        for lab in ax.get_xticklabels()
        if lab.get_text() == "Missing"
        ]
        plt.show

# %% [markdown]
# ### Marital Status by Gender

# %%
by_gender("Marital_Status", sel_rotation = 90)

# %% [markdown]
# ### Education Level by Gender

# %%
by_gender("Education_Level", sel_rotation = 90)

# %% [markdown]
# ### Smoking Status by Gender

# %%
by_gender("Smoking_Status")

# %% [markdown]
# ### Policy Type by Gender

# %%
by_gender("Policy_Type",  sel_rotation = 90)

# %% [markdown]
# ### Gender by Date | Year | Month | Day

# %% [markdown]
# ### Policy Start Date | Year

# %%
by_gender("Year", sel_rotation = 90)

# %% [markdown]
# ### Policy Start Date | Month

# %%
by_gender("Month", sel_rotation = 90, sel_aspect = 4)

# %% [markdown]
# ### Policy Start Date | Day

# %%
by_gender("Day", sel_rotation = 90, sel_aspect = 5)

# %% [markdown]
# #### WOW! I think Gender Category will not be an important feature.

# %% [markdown]
# ## Premium Amount and Annual Income

# %%
df_sample_01 = train_df.groupby("Premium_Amount").sample(frac=0.01, random_state= 8).reset_index(drop = True)

def PAAI(hue_var):
    
    sns.lmplot(
        data=df_sample_01,
        x="Premium_Amount",
        y="Annual_Income",
        height=4,
        aspect=2,
        hue=hue_var,
        scatter_kws={"s": 8, "alpha": 0.3},
        line_kws={"linewidth": 1},
    )
    plt.title(f"Premium Amount and Annual Income VS {hue_var}", fontsize=14, color="#0a2e4f")
    plt.show()

# %% [markdown]
# ### Premium Amount and Annual Income VS Year

# %%
PAAI("Year")

# %% [markdown]
# ### Premium Amount and Annual Income VS Month

# %%
PAAI("Month")

# %% [markdown]
# ### Premium Amount and Annual Income VS Smoking Status

# %%
PAAI("Smoking_Status")

# %% [markdown]
#  ### Premium Amount and Annual Income VS Education Level

# %%
PAAI("Education_Level")

# %% [markdown]
# ## Number of policies | Time series

# %% [markdown]
# ### Number of policies by Marital Status

# %%
ts_df = (
    df_sample_n.groupby(["Policy_Start_Date", "Marital_Status"])["Policy_Start_Date"]
    .count()
    .reset_index(name="Counts")
)

plt.figure(figsize=(16, 4))
sns.lineplot(
    data=ts_df,
    x="Policy_Start_Date",
    y="Counts",
    hue="Marital_Status",
    errorbar=None,
    palette=marital_status_color,
    linewidth=0.3,
)
plt.legend(ncols=4, fontsize=8, loc="upper center")
plt.show()

# %% [markdown]
# ### Even NAs are Balanced :)

# %% [markdown]
# ### Number of policies by Smoking Status

# %%
ts_df = (
    df_sample_n.groupby(["Policy_Start_Date", "Smoking_Status"])["Policy_Start_Date"]
    .count()
    .reset_index(name="Counts")
)
plt.figure(figsize=(16, 4))
sns.lineplot(
    data=ts_df,
    x="Policy_Start_Date",
    y="Counts",
    hue="Smoking_Status",
    errorbar=None,
    palette=smoking_status_color,
    linewidth=0.5,
)
plt.legend(ncols=4, fontsize=8, loc="upper center")
plt.show()

# %% [markdown]
# ### I think I have to stop here | all the same including Gender variable

# %% [markdown]
# ### Correlation Matrix

# %%
plt.style.use("default")
corr_mat = df_sample_n[num_vars].corr()
mask = np.triu(np.ones_like(corr_mat, dtype=bool))
cmap = sns.diverging_palette(230, 30, as_cmap=True)
f, ax = plt.subplots(figsize=(7, 5))
sns.heatmap(
    corr_mat,
    mask=mask,
    cbar=True,
    cmap=cmap,
    center=0,
    square=False,
    annot=False,
    linewidths=0.5,
    cbar_kws={"shrink": 0.8}
)
plt.title("Correlation Matrix\n")
plt.xticks(fontsize=9)
plt.yticks(fontsize=9)
plt.show()

# %% [markdown]
# ### Features Correlating | Premium Amount

# %%
plt.figure(figsize=(2, 4))
corr_mat2 =  df_sample_n[num_vars].corr()
sns.heatmap(
    corr_mat2[["Premium_Amount"]].sort_values(by="Premium_Amount", ascending=False),
    vmin=-1,
    vmax=1,
    cbar=False,
    annot=True,
    cmap="Blues",
    annot_kws={"fontsize":8}
)
plt.title("Features Correlating | Premium Amount", fontsize=10)
plt.xticks(fontsize=8)
plt.yticks(fontsize=8)
plt.show()

# %% [markdown]
#  ## Model

# %% [markdown]
# ### Data Transformation

# %%
train_df_fm = train_df.drop(columns=["Policy_Start_Date"], axis=1)
test_df = test_df.drop(columns=["Policy_Start_Date"], axis=1)


for i in test_num_vars:
    train_df_fm[i] = np.log1p(train_df_fm[i])
                        

X = train_df_fm.drop(columns=["Premium_Amount"], axis=1)
y = np.log(train_df_fm["Premium_Amount"])
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.2, random_state=1
)

# %% [markdown]
# ##  Lightgbm Regressor

# %% [markdown]
# ### Hyperparameter Tuning (Optuna)

# %%
def xgb_objective(trial):

    xgb_params = {
        "objective": "reg:squarederror",
        "eval_metric": "rmse",
        "enable_categorical": True,
        "n_estimators": 100,
        "max_depth": trial.suggest_int("max_depth", 7, 25),
        "learning_rate": trial.suggest_float("learning_rate", 0.01, 0.03),
        "subsample": trial.suggest_float("subsample", 0.5, 0.9),  # Similar to bagging_fraction
        "colsample_bytree": trial.suggest_float("colsample_bytree", 0.7, 0.88),  # Similar to feature_fraction
        "gamma": trial.suggest_float("gamma", 0.0, 5.0),  # Regularization
        "lambda": trial.suggest_float("lambda", 0.03, 0.05),  # L2 regularization
        "alpha": trial.suggest_float("alpha", 0.07, 0.09),  # L1 regularization
        "min_child_weight": trial.suggest_int("min_child_weight", 1, 10),
        "tree_method": "hist",  # Optimized tree method
        "random_state": 1
    }

    xgb_model = XGBRegressor(**xgb_params)

    xgb_model.fit(X_train, y_train)
    y_pred = np.exp(xgb_model.predict(X_test))
    print(rmsle(np.exp(y_test), y_pred))


    return rmsle(np.exp(y_test), y_pred)

# %% [markdown]
# ### Create a study object | optimization

# %%
study_XGBM = optuna.create_study(study_name="XGBM_Insurance", direction="minimize")
optuna.logging.set_verbosity(optuna.logging.WARNING)
study_XGBM.optimize(xgb_objective, n_trials=5, show_progress_bar=True)
# Out:
# [I 2025-04-05 16:37:21,958] A new study created in memory with name: XGBM_Insurance
# Best trial: 0. Best value: 1.05532:  20%|██        | 1/5 [01:24<05:37, 84.33s/it]
# 1.0553246792924909
# Best trial: 1. Best value: 1.04784:  40%|████      | 2/5 [01:45<02:21, 47.24s/it]
# 1.0478419705887845
# Best trial: 1. Best value: 1.04784:  60%|██████    | 3/5 [02:49<01:50, 55.00s/it]
# 1.0524402951115444
# Best trial: 3. Best value: 1.04762:  80%|████████  | 4/5 [03:01<00:38, 38.05s/it]
# 1.0476174249263168
# Best trial: 3. Best value: 1.04762: 100%|██████████| 5/5 [03:18<00:00, 39.77s/it]
# 1.0490022950352507

# %% [markdown]
# ### Best trial

# %%
print("Best trial:", study_XGBM.best_trial)
# Out:
# Best trial: FrozenTrial(number=3, state=1, values=[1.0476174249263168], datetime_start=datetime.datetime(2025, 4, 5, 16, 40, 11, 810884), datetime_complete=datetime.datetime(2025, 4, 5, 16, 40, 23, 881333), params={'max_depth': 12, 'learning_rate': 0.018016478251091546, 'subsample': 0.631384612317387, 'colsample_bytree': 0.8713202490006425, 'gamma': 3.8039743259625283, 'lambda': 0.03477973764904808, 'alpha': 0.08482946900485708, 'min_child_weight': 5}, user_attrs={}, system_attrs={}, intermediate_values={}, distributions={'max_depth': IntDistribution(high=25, log=False, low=7, step=1), 'learning_rate': FloatDistribution(high=0.03, log=False, low=0.01, step=None), 'subsample': FloatDistribution(high=0.9, log=False, low=0.5, step=None), 'colsample_bytree': FloatDistribution(high=0.88, log=False, low=0.7, step=None), 'gamma': FloatDistribution(high=5.0, log=False, low=0.0, step=None), 'lambda': FloatDistribution(high=0.05, log=False, low=0.03, step=None), 'alpha': FloatDistribution(high=0.09, log=False, low=0.07, step=None), 'min_child_weight': IntDistribution(high=10, log=False, low=1, step=1)}, trial_id=3, value=None)

# %% [markdown]
# ### Best parameters

# %%
print("Best parameters:", study_XGBM.best_params)
# Out:
# Best parameters: {'max_depth': 12, 'learning_rate': 0.018016478251091546, 'subsample': 0.631384612317387, 'colsample_bytree': 0.8713202490006425, 'gamma': 3.8039743259625283, 'lambda': 0.03477973764904808, 'alpha': 0.08482946900485708, 'min_child_weight': 5}

# %% [markdown]
# ### Visualization optimization history

# %%
import plotly
print(plotly.__version__)  # Should print a version number
# Out:
# 6.0.1

# %%
fig = optuna.visualization.plot_optimization_history(study_XGBM)
fig.update_layout(
    font_family="Courier New",
    font_size=12,
    title_font_family="Times New Roman",
    title_font_color="steelblue",
    legend_title_font_color="black",
    plot_bgcolor='#e9eff6',
    paper_bgcolor='#f5fbf5',
)
fig.update_xaxes(color = "darkgreen")
fig.update_traces(marker_color='green')

# %% [markdown]
# ### Visualization parameters importances

# %%
fig = optuna.visualization.plot_param_importances(study_XGBM)
fig.update_layout(
    font_family="Courier New",
    font_size=12,
    title_font_family="Times New Roman",
    title_font_color="steelblue",
    legend_title_font_color="black",
    plot_bgcolor='#e9eff6',
    paper_bgcolor='#f5fbf5',
)
fig.update_xaxes(color = "darkgreen")
fig.update_traces(marker_color='green')

# %% [markdown]
# ### Visualization slice

# %%
import optuna.visualization as vis

fig = vis.plot_slice(
    study_XGBM,
    params=[
        "max_depth",
        "learning_rate",
        "subsample",
        "colsample_bytree",
        "gamma",
        "lambda",             # L2 regularization
        "alpha",              # L1 regularization
        "min_child_weight",
    ],
)

fig.update_layout(
    font_family="Courier New",
    font_size=12,
    title_font_family="Times New Roman",
    title_font_color="steelblue",
    legend_title_font_color="black",
    plot_bgcolor="#e9eff6",
    paper_bgcolor="#f5fbf5",
)

fig.update_xaxes(color="darkgreen")

# %% [markdown]
# ## Train the model

# %%
from xgboost import XGBRegressor

xgbm_final = XGBRegressor(
    **study_XGBM.best_params,
    objective="reg:squarederror",       # Correct regression objective
    eval_metric="rmse",                 # Optional but recommended for regression
    n_estimators=500,                   # Override number of boosting rounds
    random_state=1,
    enable_categorical=True,            # Important for category dtype support
    tree_method="hist",                 # Required for enable_categorical
    verbosity=0                         # Instead of verbose=-1
)

xgbm_final.fit(X_train, y_train)

y_pred = np.exp(xgbm_final.predict(X_test))
print("RMSLE:", rmsle(np.exp(y_test), y_pred))
# Out:
# RMSLE: 1.0475797122647301

# %% [markdown]
# ## feature gain

# %%
import matplotlib.pyplot as plt
import xgboost as xgb

plt.rcParams['font.size'] = 5
plt.figure(figsize=(12, 6))  # Set figure size here

xgb.plot_importance(
    xgbm_final,
    importance_type="gain",
    grid=False,
    color="green"
)

plt.xticks(fontsize=9)
plt.yticks(fontsize=9)
plt.title("XGBoost Feature Importance (Gain)", fontsize=15)
plt.tight_layout()
plt.show()

# Reset to default if needed
plt.rcParams.update(plt.rcParamsDefault)

# %% [markdown]
# ## SHAP Values

# %% [markdown]
# ### Sampling for claculating SHAP values

# %%
train_df_shap = train_df.drop(columns=["Policy_Start_Date"], axis=1)
shap_df = (
    train_df_shap.groupby("Premium_Amount")[train_df_shap.columns.tolist()]
    .apply(lambda x: x.sample(frac=0.1), include_groups=True)
    .reset_index(drop=True)
    .copy()
)

############################

X_shap = shap_df.drop(["Premium_Amount"], axis=1)

# Convert all categorical features to string first (if needed), then use one-hot encoding or label encoding
X_shap_encoded = pd.get_dummies(X_shap, drop_first=True)

y_shap = np.log(shap_df["Premium_Amount"])
X_train_shap, X_test_shap, y_train_shap, y_test_shap = train_test_split(
    X_shap_encoded, y_shap, test_size=0.2, random_state=1
)


############################

xgbm_interp = XGBRegressor(
    **study_XGBM.best_params,
    objective="reg:squarederror",  # for regression
    n_estimators=500,
    random_state=1,
    verbosity=0
)
xgbm_interp.fit(X_train_shap, y_train_shap)

shap.initjs()
explainer = shap.TreeExplainer(xgbm_interp)
shap_values = explainer(X_train_shap)
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>/*! For license information please see bundle.js.LICENSE.txt */
# (()=>{var t={221:(t,n,e)=>{"use strict";var r=e(540);function i(t){var n="https://react.dev/errors/"+t;if(1<arguments.length){n+="?args[]="+encodeURIComponent(arguments[1]);for(var e=2;e<arguments.length;e++)n+="&args[]="+encodeURIComponent(arguments[e])}return"Minified React error #"+t+"; visit "+n+" for the full message or use the non-minified dev environment for full errors and additional helpful warnings."}function o(){}var u={d:{f:o,r:function(){throw Error(i(522))},D:o,C:o,L:o,m:o,X:o,S:o,M:o},p:0,findDOMNode:null},a=Symbol.for("react.portal"),c=r.__CLIENT_INTERNALS_DO_NOT_USE_OR_WARN_USERS_THEY_CANNOT_UPGRADE;function s(t,n){return"font"===t?"":"string"==typeof n?"use-credentials"===n?n:"":void 0}n.__DOM_INTERNALS_DO_NOT_USE_OR_WARN_USERS_THEY_CANNOT_UPGRADE=u,n.createPortal=function(t,n){var e=2<arguments.length&&void 0!==arguments[2]?arguments[2]:null;if(!n||1!==n.nodeType&&9!==n.nodeType&&11!==n.nodeType)throw Error(i(299));return function(t,n,e){var r=3<arguments.length&&void 0!==arguments[3]?arguments[3]:null;return{$$typeof:a,key:null==r?null:""+r,children:t,containerInfo:n,implementation:e}}(t,n,null,e)},n.flushSync=function(t){var n=c.T,e=u.p;try{if(c.T=null,u.p=2,t)return t()}finally{c.T=n,u.p=e,u.d.f()}},n.preconnect=function(t,n){"string"==typeof t&&(n=n?"string"==typeof(n=n.crossOrigin)?"use-credentials"===n?n:"":void 0:null,u.d.C(t,n))},n.prefetchDNS=function(t){"string"==typeof t&&u.d.D(t)},n.preinit=function(t,n){if("string"==typeof t&&n&&"string"==typeof n.as){var e=n.as,r=s(e,n.crossOrigin),i="string"==typeof n.integrity?n.integrity:void 0,o="string"==typeof n.fetchPriority?n.fetchPriority:void 0;"style"===e?u.d.S(t,"string"==typeof n.precedence?n.precedence:void 0,{crossOrigin:r,integrity:i,fetchPriority:o}):"script"===e&&u.d.X(t,{crossOrigin:r,integrity:i,fetchPriority:o,nonce:"string"==typeof n.nonce?n.nonce:void 0})}},n.preinitModule=function(t,n){if("string"==typeof t)if("object"==typeof n&&null!==n){if(null==n.as||"script"===n.as){var e=s(n.as,n.crossOrigin);u.d.M(t,{crossOrigin:e,integrity:"string"==typeof n.integrity?n.integrity:void 0,nonce:"string"==typeof n.nonce?n.nonce:void 0})}}else null==n&&u.d.M(t)},n.preload=function(t,n){if("string"==typeof t&&"object"==typeof n&&null!==n&&"string"==typeof n.as){var e=n.as,r=s(e,n.crossOrigin);u.d.L(t,e,{crossOrigin:r,integrity:"string"==typeof n.integrity?n.integrity:void 0,nonce:"string"==typeof n.nonce?n.nonce:void 0,type:"string"==typeof n.type?n.type:void 0,fetchPriority:"string"==typeof n.fetchPriority?n.fetchPriority:void 0,referrerPolicy:"string"==typeof n.referrerPolicy?n.referrerPolicy:void 0,imageSrcSet:"string"==typeof n.imageSrcSet?n.imageSrcSet:void 0,imageSizes:"string"==typeof n.imageSizes?n.imageSizes:void 0,media:"string"==typeof n.media?n.media:void 0})}},n.preloadModule=function(t,n){if("string"==typeof t)if(n){var e=s(n.as,n.crossOrigin);u.d.m(t,{as:"string"==typeof n.as&&"script"!==n.as?n.as:void 0,crossOrigin:e,integrity:"string"==typeof n.integrity?n.integrity:void 0})}else u.d.m(t)},n.requestFormReset=function(t){u.d.r(t)},n.unstable_batchedUpdates=function(t,n){return t(n)},n.useFormState=function(t,n,e){return c.H.useFormState(t,n,e)},n.useFormStatus=function(){return c.H.useHostTransitionStatus()},n.version="19.0.0"},540:(t,n,e)=>{"use strict";t.exports=e(869)},543:function(t,n,e){var r;t=e.nmd(t),function(){var i,o="Expected a function",u="__lodash_hash_undefined__",a="__lodash_placeholder__",c=32,s=128,f=1/0,l=9007199254740991,h=NaN,p=4294967295,v=[["ary",s],["bind",1],["bindKey",2],["curry",8],["curryRight",16],["flip",512],["partial",c],["partialRight",64],["rearg",256]],d="[object Arguments]",g="[object Array]",y="[object Boolean]",m="[object Date]",_="[object Error]",x="[object Function]",b="[object GeneratorFunction]",w="[object Map]",k="[object Number]",S="[object Object]",M="[object Promise]",A="[object RegExp]",T="[object Set]",O="[object String]",j="[object Symbol]",E="[object WeakMap]",C="[object ArrayBuffer]",$= ...

# %% [markdown]
# ### SHAP Summary | layered_violin

# %%
shap.plots.violin(
    shap_values,
    plot_type="layered_violin",
    show=False,
)
fig, ax = plt.gcf(), plt.gca()
fig.set_figheight(10)
fig.set_figwidth(7)
ax.tick_params(labelsize=8)
ax.set_title("SHAP Summary | layered_violin", fontsize=12)
plt.show()
# Out:
# /home/kishore/miniconda3/lib/python3.12/site-packages/shap/plots/_violin.py:304: UserWarning:
#
# Not enough data in bin #8 for feature Previous_Claims, so it'll be ignored. Try increasing the number of records to plot.

# %% [markdown]
# ### Feature Importance | SHAP

# %%
shap.plots.bar(shap_values, max_display=15, show=False)
fig, ax = plt.gcf(), plt.gca()
fig.set_figheight(6)
fig.set_figwidth(7)
ax.tick_params(labelsize=8)
plt.show()

# %% [markdown]
# ### Waterfall Plot

# %%
index = 2
shap.plots.waterfall(shap_values[index], show=False)
fig, ax = plt.gcf(), plt.gca()
fig.set_figheight(5)
fig.set_figwidth(7)
plt.show()

# %% [markdown]
# ### Force Plot

# %%
shap.plots.force(
    shap_values[index],
    text_rotation=90,
    matplotlib=True,
    figsize=(25, 3),
    contribution_threshold=0.005,
    out_names=f" Age: {shap_values[index].data[0]} | {shap_values[index].data[1]}",
)

# %% [markdown]
# ## Make predictions on Test Dataset

# %%
for i in test_num_vars:
    test_df[i] = np.log1p(test_df[i])



y_pred_test = np.exp(xgbm_final.predict(test_df))
y_pred_test
# Out:
# array([697.6783 , 431.25476, 433.59653, ..., 376.42108, 379.41806,
#        490.68866], dtype=float32)

# %% [markdown]
# ## Submission

# %%
sample_submission["Premium Amount"] =  y_pred_test

sample_submission.to_csv('submission.csv',index=False)
sample_submission
# Out:
#              id  Premium Amount
# 0       1200000      697.678284
# 1       1200001      431.254761
# 2       1200002      433.596527
# 3       1200003      567.065369
# 4       1200004      483.113007
# ...         ...             ...
# 799995  1999995      374.231171
# 799996  1999996      437.152771
# 799997  1999997      376.421082
# 799998  1999998      379.418060
# 799999  1999999      490.688660
#
# [800000 rows x 2 columns]

# %% [markdown]
# ## Premium Amount Distribution | Predictions

# %%
mean_premium_amount = sample_submission["Premium Amount"].mean().squeeze()

fig, (ax1, ax2) = plt.subplots(2, figsize=(10, 4))

sns.histplot(
    data=sample_submission, x="Premium Amount", color="#00ccff", bins=40, alpha=0.7, lw=0.1, ax=ax1
)

sns.boxplot(
    data=sample_submission,
    x="Premium Amount",
    color="#00ccff",
    linewidth=0.3,
    flierprops=dict(
        marker="o", markersize=4, markerfacecolor="darkred", markeredgecolor="darkred"
    ),
    boxprops=dict(alpha=0.7),
    ax=ax2,
)
ax2.set_title("")
ax2.set_xlabel("Premium Amount | Predictions", fontsize=12)

ax1.set_title("Premium Amount Distribution | Predictions", fontsize=12)
ax1.set_xlabel("")

ax1.axvline(x=mean_premium_amount, color="darkred", ls="--", lw=1.5)
ax1.text(
    mean_premium_amount + 20,
    200000,
    "Mean Premium Amount | Predictions | " + str(mean_premium_amount.round(0)),
    fontsize=9,
    color="#000000",
)

plt.show()
